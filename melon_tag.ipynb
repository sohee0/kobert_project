# %% [markdown]
# 공포:0, 놀람:1, 분노:2, 혐오:3, 슬픔:4, 행복:5

# %%
import pandas as pd

# %%
melon_df = pd.read_csv('/content/drive/MyDrive/딥러닝 미니프로젝트/data/emo_tag_final.csv',index_col=0)
melon_df
# Out:
#           id                    plylst_title  \
# 1     111944                        신화를 추억하며
# 3      46611                 아버지 어머니께 바치는 노래
# 4      20864                추억에 젖는 25살의 학창시절
# 6      12697                          추억의ost
# 7      15920               토토가 덕분에 다시듣는 명곡들!
# ...      ...                             ...
# 6667   90220                     스트레스 저리 비켜!
# 6669  101698                 스트레스엔 스타리그BGM!!
# 6670    4504  80년생들은 한번쯤 흥얼거렸을 법한 스트레스 해소 가요
# 6671   38264          선정성 안무로 방송금지된 걸그룹 노래모음
# 6672    2574                  올한해의 아이돌 히트곡들!
#
#                                                   songs  like_cnt         tag  \
# 1     [23743, 698749, 402171, 421925, 388924, 102519...        12      추억, 회상
# 3     [138932, 176304, 473514, 78625, 251980, 212909...        17      추억, 회상
# 4     [391924, 629705, 198747, 506139, 333925, 38356...         5      추억, 회상
# 6     [636163, 354666, 106249, 320601, 386522, 41898...         3      추억, 회상
# 7     [371691, 326088, 438424, 539090, 275179, 82293...        19      추억, 회상
# ...                                                 ...       ...         ...
# 6667  [700090, 433453, 125822, 440239, 193571, 27358...        30  기분전환, 스트레스
# 6669  [596414, 494891, 524265, 211325, 652662, 55421...        11  기분전환, 스트레스
# 6670  [689057, 123294, 263272, 14156, 615586, 80656,...       277  기분전환, 스트레스
# 6671  [104087, 233074, 527255, 34363, 284159, 447424...        49  기분전환, 스트레스
# 6672  [492163, 699874, 360197, 355939, 498935, 32282...        36  드라이브, 스트레스
#
#      Emotion  plylst_cnt
# 1         슬픔         372
# 3         슬픔         372
# 4         슬픔         372
# 6         슬픔         372
# 7         슬픔         372
# ...      ...         ...
# 6667    분노혐오         622
# 6669    분노혐오         622
# 6670    분노혐오         622
# 6671    분노혐오         622
# 6672    분노혐오         110
#
# [5237 rows x 7 columns]

# %%
melon_df.groupby('Emotion').count()
# Out:
#            id  plylst_title  songs  like_cnt   tag  plylst_cnt
# Emotion
# 공포놀람     1249          1249   1249      1249  1249        1249
# 분노혐오     1351          1351   1351      1351  1351        1351
# 슬픔       1298          1298   1298      1298  1298        1298
# 행복       1339          1339   1339      1339  1339        1339

# %%
melon_df.groupby('tag').count()
# Out:
#                id  plylst_title  songs  like_cnt  Emotion  plylst_cnt
# tag
# 가을            149           149    149       149      149         149
# 가을, 까페        115           115    115       115      115         115
# 가을, 잔잔한       111           111    111       111      111         111
# 감성             72            72     72        72       72          72
# 겨울            136           136    136       136      136         136
# 겨울, 까페        106           106    106       106      106         106
# 기분전환          445           445    445       445      445         445
# 기분전환, 까페      162           162    162       162      162         162
# 기분전환, 드라이브    415           415    415       415      415         415
# 기분전환, 밤, 새벽   160           160    160       160      160         160
# 기분전환, 스트레스      6             6      6         6        6           6
# 기분전환, 운동      189           189    189       189      189         189
# 기분전환, 잔잔한     107           107    107       107      107         107
# 까페            156           156    156       156      156         156
# 까페, 잔잔한       193           193    193       193      193         193
# 드라이브          182           182    182       182      182         182
# 드라이브, 스트레스      1             1      1         1        1           1
# 드라이브, 운동      146           146    146       146      146         146
# 밤, 새벽         219           219    219       219      219         219
# 봄              95            95     95        95       95          95
# 비오는날          118           118    118       118      118         118
# 비오는날, 슬픔, 이별  147           147    147       147      147         147
# 비오는날, 잔잔한     146           146    146       146      146         146
# 사랑, 설렘, 잔잔한    14            14     14        14       14          14
# 산책, 여행         16            16     16        16       16          16
# 스트레스, 운동      172           172    172       172      172         172
# 슬픔, 이별        247           247    247       247      247         247
# 슬픔, 이별, 잔잔한   144           144    144       144      144         144
# 여름             80            80     80        80       80          80
# 운동             86            86     86        86       86          86
# 잔잔한           145           145    145       145      145         145
# 잔잔한, 추억, 회상   308           308    308       308      308         308
# 추억, 회상        277           277    277       277      277         277
# 클럽             98            98     98        98       98          98
# 휴식, 힐링         74            74     74        74       74          74

# %%
melon_df.loc[(melon_df['tag']=='기분전환'),'Emotion']='공포'

# %%
melon_df.groupby('Emotion').count()
# Out:
#            id  plylst_title  songs  like_cnt   tag  plylst_cnt
# Emotion
# 공포        556           556    556       556   556         556
# 놀람        693           693    693       693   693         693
# 분노        771           771    771       771   771         771
# 슬픔       1298          1298   1298      1298  1298        1298
# 행복       1339          1339   1339      1339  1339        1339
# 혐오        580           580    580       580   580         580

# %%
melon_df.loc[(melon_df['tag']=='가을, 잔잔한'),'Emotion']='공포'

# %%
melon_df.loc[(melon_df['tag']=='기분전환, 까페'),'Emotion']='공포놀람'

# %%
melon_df.loc[(melon_df['Emotion']=='공포놀람'),'Emotion']='놀람'

# %%
melon_df.loc[(melon_df['tag']=='기분전환, 운동'),'Emotion']='혐오'

# %%
melon_df.loc[(melon_df['tag']=='스트레스, 운동'),'Emotion']='혐오'

# %%
melon_df.loc[(melon_df['tag']=='휴식, 힐링'),'Emotion']='혐오'

# %%
melon_df.loc[(melon_df['tag']=='잔잔한'),'Emotion']='혐오'

# %%
melon_df.loc[(melon_df['Emotion']=='분노혐오'),'Emotion']='분노'

# %%
melon_df.to_csv('/content/drive/MyDrive/딥러닝 미니프로젝트/data/melon_label.csv',encoding='utf-8',index=True)

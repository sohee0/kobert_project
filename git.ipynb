# %%
cd /content/drive/MyDrive/git_commit
# Out:
# /content/drive/MyDrive/git_commit

# %%
# !git clone https://sohee0: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@github.com/sohee0/kobert_project.git
# Out:
# Cloning into 'kobert_project'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), done.

# %%
cd kobert_project
# Out:
# /content/drive/MyDrive/git_commit/kobert_project

# %%
# !git config --global user.email 'sh0818k@gmail.com'
# !git config --global user.name 'sohee0'

# %%
# !git add
# Out:
# fatal: pathspec 'kobert_project' did not match any files
